# %%
import numpy as np
from itertools import permutations, product

# %%
currencies = ["Snowballs", "Pizzas", "Silicon Nuggets", "SeaShells"]

exchange_rates = np.array([
    [1.0, 1.45, 0.52, 0.72],  
    [0.70, 1.0, 0.31, 0.48],  
    [1.95, 3.10, 1.0, 1.49],  
    [1.34, 1.98, 0.64, 1.0]   
])

currency_indices = {curr: i for i, curr in enumerate(currencies)}

def calculate_profit(path):
    value = 1.0  
    for i in range(len(path) - 1):
        from_currency = path[i]
        to_currency = path[i+1]
        from_idx = currency_indices[from_currency]
        to_idx = currency_indices[to_currency]
        exchange_rate = exchange_rates[from_idx, to_idx]
        value *= exchange_rate
    return value

def generate_valid_paths(max_trades=5):
    valid_paths = []
    
    for num_trades in range(1, max_trades + 1):
        path_length = num_trades + 1
        
        if num_trades == 1:
            for curr in currencies:
                if curr != "SeaShells":
                    valid_paths.append(["SeaShells", curr, "SeaShells"])
        else:
            for combo in product(currencies, repeat=num_trades - 1):
                path = ["SeaShells"]
                
                valid_intermediate = True
                last_currency = "SeaShells"
                
                for curr in combo:
                    if curr == last_currency:
                        valid_intermediate = False
                        break
                    path.append(curr)
                    last_currency = curr
                
                if valid_intermediate and last_currency != "SeaShells":
                    path.append("SeaShells")
                    valid_paths.append(path)
    
    return valid_paths

def rank_all_strategies(max_trades=5):
    valid_paths = generate_valid_paths(max_trades)
    
    path_profits = [(path, calculate_profit(path), len(path)-1) for path in valid_paths]
    
    path_profits.sort(key=lambda x: x[1], reverse=True)
    
    return path_profits

# %%
all_strategies = rank_all_strategies(5)

print(f"All Trading Strategies ({len(all_strategies)} total):")
print("Rank | Trading Path | # Trades | Profit | Profit %")
print("-" * 80)

for i, (path, profit, num_trades) in enumerate(all_strategies, 1):
    path_str = " → ".join(path)
    profit_percentage = (profit - 1) * 100
    print(f"{i:4d} | {path_str} | {num_trades} | {profit:.4f} | {profit_percentage:+.2f}%")

best_path, best_profit, best_trades = all_strategies[0]
worst_path, worst_profit, worst_trades = all_strategies[-1]

print("\nBest Strategy:")
print(f"Path: {' → '.join(best_path)}")
print(f"Number of trades: {best_trades}")
print(f"Profit: {best_profit:.4f} ({(best_profit - 1) * 100:+.2f}%)")

print("\nWorst Strategy:")
print(f"Path: {' → '.join(worst_path)}")
print(f"Number of trades: {worst_trades}")
print(f"Profit: {worst_profit:.4f} ({(worst_profit - 1) * 100:+.2f}%)")

profitable_strategies = sum(1 for _, profit, _ in all_strategies if profit > 1)
breakeven_strategies = sum(1 for _, profit, _ in all_strategies if profit == 1)
losing_strategies = sum(1 for _, profit, _ in all_strategies if profit < 1)

print("\nStrategy Distribution:")
print(f"Profitable strategies: {profitable_strategies} ({profitable_strategies/len(all_strategies)*100:.1f}%)")
print(f"Breakeven strategies: {breakeven_strategies} ({breakeven_strategies/len(all_strategies)*100:.1f}%)")
print(f"Losing strategies: {losing_strategies} ({losing_strategies/len(all_strategies)*100:.1f}%)")
# Out:
# All Trading Strategies (93 total):
# Rank | Trading Path | # Trades | Profit | Profit %
# --------------------------------------------------------------------------------
#    1 | SeaShells → Snowballs → Silicon Nuggets → Pizzas → Snowballs → SeaShells | 5 | 1.0887 | +8.87%
#    2 | SeaShells → Silicon Nuggets → Pizzas → Snowballs → Silicon Nuggets → SeaShells | 5 | 1.0760 | +7.60%
#    3 | SeaShells → Pizzas → Snowballs → Silicon Nuggets → SeaShells | 4 | 1.0739 | +7.39%
#    4 | SeaShells → Pizzas → Snowballs → Silicon Nuggets → Pizzas → SeaShells | 5 | 1.0724 | +7.24%
#    5 | SeaShells → Snowballs → Pizzas → Snowballs → Silicon Nuggets → SeaShells | 5 | 1.0538 | +5.38%
#    6 | SeaShells → Snowballs → Silicon Nuggets → Snowballs → Silicon Nuggets → SeaShells | 5 | 1.0528 | +5.28%
#    7 | SeaShells → Snowballs → Silicon Nuggets → SeaShells | 3 | 1.0382 | +3.82%
#    8 | SeaShells → Snowballs → Silicon Nuggets → Pizzas → SeaShells | 4 | 1.0368 | +3.68%
#    9 | SeaShells → Pizzas → Snowballs → Pizzas → Snowballs → SeaShells | 5 | 1.0129 | +1.29%
#   10 | SeaShells → Pizzas → Snowballs → Silicon Nuggets → Snowballs → SeaShells | 5 | 1.0119 | +1.19%
#   11 | SeaShells → Snowballs → Silicon Nuggets → SeaShells → Snowballs → SeaShells | 5 | 1.0017 | +0.17%
#   12 | SeaShells → Snowballs → SeaShells → Snowballs → Silicon Nuggets → SeaShells | 5 | 1.0017 | +0.17%
#   13 | SeaShells → Silicon Nuggets → Pizzas → Snowballs → SeaShells | 4 | 0.9999 | -0.01%
#   14 | SeaShells → Pizzas → Snowballs → SeaShells | 3 | 0.9979 | -0.21%
#   15 | SeaShells → Snowballs → Silicon Nuggets → Pizzas → Silicon Nuggets → SeaShells | 5 | 0.9977 | -0.23%
#   16 | SeaShells → Snowballs → Silicon Nuggets → SeaShells → Silicon Nuggets → SeaShells | 5 | 0.9901 | -0.99%
#   17 | SeaShells → Silicon Nuggets → SeaShells → Snowballs → Silicon Nuggets → SeaShells | 5 | 0.9901 | -0.99%
#   18 | SeaShells → Snowballs → Silicon Nuggets → SeaShells → Pizzas → SeaShells | 5 | 0.9867 | -1.33%
#   19 | SeaShells → Pizzas → SeaShells → Snowballs → Silicon Nuggets → SeaShells | 5 | 0.9867 | -1.33%
#   20 | SeaShells → Snowballs → Pizzas → Snowballs → SeaShells | 4 | 0.9793 | -2.07%
#   21 | SeaShells → Snowballs → Silicon Nuggets → Snowballs → SeaShells | 4 | 0.9783 | -2.17%
#   22 | SeaShells → Silicon Nuggets → Snowballs → Silicon Nuggets → SeaShells | 4 | 0.9670 | -3.30%
#   23 | SeaShells → Silicon Nuggets → Pizzas → Snowballs → Pizzas → SeaShells | 5 | 0.9666 | -3.34%
#   24 | SeaShells → Silicon Nuggets → Snowballs → Silicon Nuggets → Pizzas → SeaShells | 5 | 0.9657 | -3.43%
#   25 | SeaShells → Snowballs → SeaShells | 2 | 0.9648 | -3.52%
#   26 | SeaShells → Snowballs → SeaShells | 2 | 0.9648 | -3.52%
#   27 | SeaShells → Pizzas → Snowballs → Pizzas → SeaShells | 4 | 0.9647 | -3.53%
#   28 | SeaShells → Snowballs → SeaShells → Pizzas → Snowballs → SeaShells | 5 | 0.9628 | -3.72%
#   29 | SeaShells → Pizzas → Snowballs → SeaShells → Snowballs → SeaShells | 5 | 0.9628 | -3.72%
#   30 | SeaShells → Pizzas → Silicon Nuggets → Pizzas → Snowballs → SeaShells | 5 | 0.9590 | -4.10%
#   31 | SeaShells → Silicon Nuggets → SeaShells | 2 | 0.9536 | -4.64%
#   32 | SeaShells → Silicon Nuggets → SeaShells | 2 | 0.9536 | -4.64%
#   33 | SeaShells → Silicon Nuggets → Pizzas → SeaShells | 3 | 0.9523 | -4.77%
#   34 | SeaShells → Silicon Nuggets → SeaShells → Pizzas → Snowballs → SeaShells | 5 | 0.9516 | -4.84%
#   35 | SeaShells → Pizzas → Snowballs → SeaShells → Silicon Nuggets → SeaShells | 5 | 0.9516 | -4.84%
#   36 | SeaShells → Pizzas → SeaShells | 2 | 0.9504 | -4.96%
#   37 | SeaShells → Pizzas → SeaShells | 2 | 0.9504 | -4.96%
#   38 | SeaShells → Pizzas → Snowballs → SeaShells → Pizzas → SeaShells | 5 | 0.9484 | -5.16%
#   39 | SeaShells → Pizzas → SeaShells → Pizzas → Snowballs → SeaShells | 5 | 0.9484 | -5.16%
#   40 | SeaShells → Snowballs → Pizzas → Snowballs → Pizzas → SeaShells | 5 | 0.9466 | -5.34%
#   41 | SeaShells → Snowballs → Silicon Nuggets → Snowballs → Pizzas → SeaShells | 5 | 0.9457 | -5.43%
#   42 | SeaShells → Snowballs → Pizzas → SeaShells | 3 | 0.9326 | -6.74%
#   43 | SeaShells → Snowballs → SeaShells → Snowballs → SeaShells | 4 | 0.9308 | -6.92%
#   44 | SeaShells → Pizzas → Snowballs → Pizzas → Silicon Nuggets → SeaShells | 5 | 0.9283 | -7.17%
#   45 | SeaShells → Pizzas → Silicon Nuggets → Snowballs → Silicon Nuggets → SeaShells | 5 | 0.9274 | -7.26%
#   46 | SeaShells → Snowballs → SeaShells → Silicon Nuggets → SeaShells | 4 | 0.9200 | -8.00%
#   47 | SeaShells → Silicon Nuggets → SeaShells → Snowballs → SeaShells | 4 | 0.9200 | -8.00%
#   48 | SeaShells → Snowballs → SeaShells → Silicon Nuggets → Pizzas → SeaShells | 5 | 0.9188 | -8.12%
#   49 | SeaShells → Silicon Nuggets → Pizzas → SeaShells → Snowballs → SeaShells | 5 | 0.9188 | -8.12%
#   50 | SeaShells → Snowballs → SeaShells → Pizzas → SeaShells | 4 | 0.9169 | -8.31%
#   51 | SeaShells → Pizzas → SeaShells → Snowballs → SeaShells | 4 | 0.9169 | -8.31%
#   52 | SeaShells → Silicon Nuggets → Pizzas → Silicon Nuggets → SeaShells | 4 | 0.9164 | -8.36%
#   53 | SeaShells → Silicon Nuggets → Pizzas → Silicon Nuggets → Pizzas → SeaShells | 5 | 0.9152 | -8.48%
#   54 | SeaShells → Pizzas → Silicon Nuggets → SeaShells | 3 | 0.9146 | -8.54%
#   55 | SeaShells → Pizzas → Silicon Nuggets → Pizzas → SeaShells | 4 | 0.9133 | -8.67%
#   56 | SeaShells → Silicon Nuggets → Snowballs → Pizzas → Snowballs → SeaShells | 5 | 0.9120 | -8.80%
#   57 | SeaShells → Silicon Nuggets → Snowballs → Silicon Nuggets → Snowballs → SeaShells | 5 | 0.9111 | -8.89%
#   58 | SeaShells → Silicon Nuggets → SeaShells → Silicon Nuggets → SeaShells | 4 | 0.9094 | -9.06%
#   59 | SeaShells → Silicon Nuggets → Pizzas → SeaShells → Silicon Nuggets → SeaShells | 5 | 0.9081 | -9.19%
#   60 | SeaShells → Silicon Nuggets → SeaShells → Silicon Nuggets → Pizzas → SeaShells | 5 | 0.9081 | -9.19%
#   61 | SeaShells → Silicon Nuggets → SeaShells → Pizzas → SeaShells | 4 | 0.9063 | -9.37%
#   62 | SeaShells → Pizzas → SeaShells → Silicon Nuggets → SeaShells | 4 | 0.9063 | -9.37%
#   63 | SeaShells → Silicon Nuggets → Pizzas → SeaShells → Pizzas → SeaShells | 5 | 0.9051 | -9.49%
#   64 | SeaShells → Pizzas → SeaShells → Silicon Nuggets → Pizzas → SeaShells | 5 | 0.9051 | -9.49%
#   65 | SeaShells → Pizzas → SeaShells → Pizzas → SeaShells | 4 | 0.9033 | -9.67%
#   66 | SeaShells → Snowballs → Pizzas → SeaShells → Snowballs → SeaShells | 5 | 0.8998 | -10.02%
#   67 | SeaShells → Snowballs → SeaShells → Snowballs → Pizzas → SeaShells | 5 | 0.8998 | -10.02%
#   68 | SeaShells → Silicon Nuggets → Snowballs → SeaShells | 3 | 0.8986 | -10.14%
#   69 | SeaShells → Snowballs → Pizzas → Silicon Nuggets → SeaShells | 4 | 0.8975 | -10.25%
#   70 | SeaShells → Snowballs → Pizzas → Silicon Nuggets → Pizzas → SeaShells | 5 | 0.8963 | -10.37%
#   71 | SeaShells → Snowballs → Pizzas → SeaShells → Silicon Nuggets → SeaShells | 5 | 0.8894 | -11.06%
#   72 | SeaShells → Silicon Nuggets → SeaShells → Snowballs → Pizzas → SeaShells | 5 | 0.8894 | -11.06%
#   73 | SeaShells → Snowballs → Pizzas → SeaShells → Pizzas → SeaShells | 5 | 0.8864 | -11.36%
#   74 | SeaShells → Pizzas → SeaShells → Snowballs → Pizzas → SeaShells | 5 | 0.8864 | -11.36%
#   75 | SeaShells → Snowballs → SeaShells → Pizzas → Silicon Nuggets → SeaShells | 5 | 0.8824 | -11.76%
#   76 | SeaShells → Pizzas → Silicon Nuggets → SeaShells → Snowballs → SeaShells | 5 | 0.8824 | -11.76%
#   77 | SeaShells → Pizzas → Silicon Nuggets → Pizzas → Silicon Nuggets → SeaShells | 5 | 0.8789 | -12.11%
#   78 | SeaShells → Pizzas → Silicon Nuggets → SeaShells → Silicon Nuggets → SeaShells | 5 | 0.8721 | -12.79%
#   79 | SeaShells → Silicon Nuggets → SeaShells → Pizzas → Silicon Nuggets → SeaShells | 5 | 0.8721 | -12.79%
#   80 | SeaShells → Pizzas → SeaShells → Pizzas → Silicon Nuggets → SeaShells | 5 | 0.8692 | -13.08%
#   81 | SeaShells → Pizzas → Silicon Nuggets → SeaShells → Pizzas → SeaShells | 5 | 0.8692 | -13.08%
#   82 | SeaShells → Silicon Nuggets → Snowballs → Pizzas → SeaShells | 4 | 0.8686 | -13.14%
#   83 | SeaShells → Snowballs → SeaShells → Silicon Nuggets → Snowballs → SeaShells | 5 | 0.8669 | -13.31%
#   84 | SeaShells → Silicon Nuggets → Snowballs → SeaShells → Snowballs → SeaShells | 5 | 0.8669 | -13.31%
#   85 | SeaShells → Silicon Nuggets → Pizzas → Silicon Nuggets → Snowballs → SeaShells | 5 | 0.8635 | -13.65%
#   86 | SeaShells → Pizzas → Silicon Nuggets → Snowballs → SeaShells | 4 | 0.8618 | -13.82%
#   87 | SeaShells → Silicon Nuggets → SeaShells → Silicon Nuggets → Snowballs → SeaShells | 5 | 0.8569 | -14.31%
#   88 | SeaShells → Silicon Nuggets → Snowballs → SeaShells → Silicon Nuggets → SeaShells | 5 | 0.8569 | -14.31%
#   89 | SeaShells → Silicon Nuggets → Snowballs → SeaShells → Pizzas → SeaShells | 5 | 0.8540 | -14.60%
#   90 | SeaShells → Pizzas → SeaShells → Silicon Nuggets → Snowballs → SeaShells | 5 | 0.8540 | -14.60%
#   91 | SeaShells → Snowballs → Pizzas → Silicon Nuggets → Snowballs → SeaShells | 5 | 0.8457 | -15.43%
#   92 | SeaShells → Silicon Nuggets → Snowballs → Pizzas → Silicon Nuggets → SeaShells | 5 | 0.8359 | -16.41%
#   93 | SeaShells → Pizzas → Silicon Nuggets → Snowballs → Pizzas → SeaShells | 5 | 0.8330 | -16.70%
#
# Best Strategy:
# Path: SeaShells → Snowballs → Silicon Nuggets → Pizzas → Snowballs → SeaShells
# Number of trades: 5
# Profit: 1.0887 (+8.87%)
#
# Worst Strategy:
# Path: SeaShells → Pizzas → Silicon Nuggets → Snowballs → Pizzas → SeaShells
# Number of trades: 5
# Profit: 0.8330 (-16.70%)
#
# Strategy Distribution:
# Profitable strategies: 12 (12.9%)
# Breakeven strategies: 0 (0.0%)
# Losing strategies: 81 (87.1%)
